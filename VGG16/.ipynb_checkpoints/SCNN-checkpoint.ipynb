# %%
import itertools
import matplotlib
import os
import re
import tensorflow
import time
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

from tensorflow.keras import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical, plot_model

matplotlib.rcParams['axes.labelsize'] = 20
matplotlib.rcParams['figure.figsize'] = 16, 10
matplotlib.rcParams['text.color'] 
matplotlib.rcParams['xtick.labelsize'] = 20
matplotlib.rcParams['ytick.labelsize'] = 20

os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

plt.style.use('fivethirtyeight')

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

warnings.filterwarnings('ignore')

epochs = 50
batch_size = 250
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999)

# %%
def display_errors(errors_index, img_errors, pred_errors, obs_errors, x, y, nrows, ncols):
    n = 0
    nrows = nrows
    ncols = ncols
    fig, ax = plt.subplots(nrows, ncols, sharex=True, sharey=True, figsize=(10, 10))
    plt.subplots_adjust(wspace=0.5, hspace=0.5)
    
    for row in range(nrows):
        for col in range(ncols):
            error = errors_index[n]
            ax[row, col].imshow((img_errors[error]).reshape((x, y)),  cmap = "gray")
            ax[row, col].set_title("Predicted label: {}\nTrue label: {}".format(pred_errors[error], obs_errors[error]))
            ax[row, col].set_xticks([])
            ax[row, col].set_yticks([])
            ax[row, col].set_xticklabels([])
            ax[row, col].set_yticklabels([])
            n += 1

# %%
(X_train_MNIST, Y_train_MNIST), (X_test_MNIST, Y_test_MNIST) = mnist.load_data()

# %%
Y_MNIST = np.concatenate((Y_train_MNIST, Y_test_MNIST), axis = None)

# %%
plt.figure()
g = sns.countplot(Y_MNIST, palette="icefire")
plt.title("Number of Digits Per Class", fontsize = '24')
plt.xticks(fontsize = '20')
plt.yticks(fontsize = '20')
plt.xlabel("Label", fontsize = '24')
plt.ylabel("Count", fontsize = '24')
Values, Counts = np.unique(Y_MNIST, return_counts=True)

# %%
VC_MNIST = pd.DataFrame({'Values': Values, 'Counts': Counts})
VC_MNIST = VC_MNIST.style.hide_index()
VC_MNIST
# Out:
# <style  type="text/css" >
# </style><table id="T_d568a_" ><thead>    <tr>        <th class="col_heading level0 col0" >Values</th>        <th class="col_heading level0 col1" >Counts</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_d568a_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_d568a_row0_col1" class="data row0 col1" >6903</td>
#             </tr>
#             <tr>
#                                 <td id="T_d568a_row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_d568a_row1_col1" class="data row1 col1" >7877</td>
#             </tr>
#             <tr>
#                                 <td id="T_d568a_row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_d568a_row2_col1" class="data row2 col1" >6990</td>
#             </tr>
#             <tr>
#                                 <td id="T_d568a_row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_d568a_row3_col1" class="data row3 col1" >7141</td>
#             </tr>
#             <tr>
#                                 <td id="T_d568a_row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_d568a_row4_col1" class="data row4 col1" >6824</td>
#             </tr>
#             <tr>
#                                 <td id="T_d568a_row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_d568a_row5_col1" class="data row5 col1" >6313</td>
#             </tr>
#             <tr>
#                                 <td id="T_d568a_row6_col0" class="data row6 col0" >6</td>
#                         <td id="T_d568a_row6_col1" class="data row6 col1" >6876</td>
#             </tr>
#             <tr>
#                                 <td id="T_d568a_row7_col0" class="data row7 col0" >7</td>
#                         <td id="T_d568a_row7_col1" class="data row7 col1" >7293</td>
#             </tr>
#             <tr>
#                                 <td id="T_d568a_row8_col0" class="data row8 col0" >8</td>
#                         <td id="T_d568a_row8_col1" class="data row8 col1" >6825</td>
#             </tr>
#             <tr>
#                                 <td id="T_d568a_row9_col0" class="data row9 col0" >9</td>
#                         <td id="T_d568a_row9_col1" class="data row9 col1" >6958</td>
#             </tr>
#     </tbody></table>

# %%
X_train_MNIST = X_train_MNIST / 255.
X_test_MNIST = X_test_MNIST / 255.

# %%
X_train_MNIST = X_train_MNIST.reshape(-1, 28, 28, 1)
X_test_MNIST = X_test_MNIST.reshape (-1, 28, 28, 1)
X_train_MNIST.shape, X_train_MNIST.shape
# Out:
# ((60000, 28, 28, 1), (60000, 28, 28, 1))

# %%
Y_train_MNIST = to_categorical(Y_train_MNIST)
Y_test_MNIST = to_categorical(Y_test_MNIST)
Y_train_MNIST.shape, Y_test_MNIST.shape
# Out:
# ((60000, 10), (10000, 10))

# %%
num = 20
images = X_train_MNIST[:num]

num_row = 5
num_col = 4

fig, axes = plt.subplots(num_row, num_col, figsize=(10, 10))

for i in range(num):
    ax = axes[i // num_col, i % num_col]
    ax.imshow(images[i].reshape(28, 28), cmap='gray')
    ax.set_title('Label: {}'.format(Y_train_MNIST[i].tolist().index(1.0, 0, 10)))
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xticklabels([])
    ax.set_yticklabels([])

plt.tight_layout()
plt.show()

# %%
X_train_MNIST, X_val_MNIST, Y_train_MNIST, Y_val_MNIST = train_test_split(X_train_MNIST, Y_train_MNIST, test_size = 0.2, random_state=10)
X_train_MNIST.shape, X_val_MNIST.shape, Y_train_MNIST.shape, Y_val_MNIST.shape
# Out:
# ((48000, 28, 28, 1), (12000, 28, 28, 1), (48000, 10), (12000, 10))

# %%
reduce_learning = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=2,
    verbose=1,
    mode='auto',
    min_delta=0.0001,
    cooldown=2,
    min_lr=0)

eary_stopping = EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=7,
    verbose=1,
    mode='auto')

callbacks = [reduce_learning, eary_stopping]

# %%
model_MNIST = Sequential()
model_MNIST.add(Conv2D(filters = 8, kernel_size = (5, 5), padding = 'Same', activation = 'relu', input_shape = (28, 28, 1)))
model_MNIST.add(MaxPool2D(pool_size=(2, 2)))
model_MNIST.add(Dropout(0.25))
model_MNIST.add(Conv2D(filters = 16, kernel_size = (3, 3), padding = 'Same', activation = 'relu'))
model_MNIST.add(MaxPool2D(pool_size = (2, 2), strides = (2, 2)))
model_MNIST.add(Dropout(0.25))
model_MNIST.add(Flatten())
model_MNIST.add(Dense(256, activation = "relu"))
model_MNIST.add(Dropout(0.5))
model_MNIST.add(Dense(10, activation = "softmax"))
model_MNIST.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 8)         208
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 8)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 8)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 16)        1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 16)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 204,906
# Trainable params: 204,906
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model_MNIST, "MNIST_Classifier.png", show_shapes=True)
# Out:
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.

# %%
model_MNIST.compile(optimizer = optimizer, loss = "categorical_crossentropy", metrics=["accuracy"])

# %%
datagen_MNIST = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # dimesion reduction
        rotation_range=5,  # randomly rotate images in the range 5 degrees
        zoom_range = 0.1, # Randomly zoom image 10%
        width_shift_range=0.1,  # randomly shift images horizontally 10%
        height_shift_range=0.1,  # randomly shift images vertically 10%
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

datagen_MNIST.fit(X_train_MNIST)

# %%
history_MNIST = model_MNIST.fit_generator(datagen_MNIST.flow(X_train_MNIST, Y_train_MNIST, batch_size = batch_size), epochs = epochs, validation_data = (X_val_MNIST, Y_val_MNIST), steps_per_epoch = X_train_MNIST.shape[0] // batch_size, callbacks = callbacks)
# Out:
# WARNING:tensorflow:From <ipython-input-17-706f2d6cfbad>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 192 steps, validate on 12000 samples
# Epoch 1/50
# 192/192 [==============================] - 9s 44ms/step - loss: 0.9492 - accuracy: 0.6821 - val_loss: 0.1750 - val_accuracy: 0.9520
# Epoch 2/50
# 192/192 [==============================] - 7s 38ms/step - loss: 0.3744 - accuracy: 0.8829 - val_loss: 0.1080 - val_accuracy: 0.9686
# Epoch 3/50
# 192/192 [==============================] - 7s 37ms/step - loss: 0.2850 - accuracy: 0.9119 - val_loss: 0.0883 - val_accuracy: 0.9730
# Epoch 4/50
# 192/192 [==============================] - 7s 37ms/step - loss: 0.2382 - accuracy: 0.9264 - val_loss: 0.0779 - val_accuracy: 0.9758
# Epoch 5/50
# 192/192 [==============================] - 7s 37ms/step - loss: 0.2152 - accuracy: 0.9359 - val_loss: 0.0706 - val_accuracy: 0.9787
# Epoch 6/50
# 192/192 [==============================] - 7s 38ms/step - loss: 0.1941 - accuracy: 0.9413 - val_loss: 0.0668 - val_accuracy: 0.9793
# Epoch 7/50
# 192/192 [==============================] - 7s 38ms/step - loss: 0.1831 - accuracy: 0.9441 - val_loss: 0.0654 - val_accuracy: 0.9795
# Epoch 8/50
# 192/192 [==============================] - 7s 38ms/step - loss: 0.1729 - accuracy: 0.9465 - val_loss: 0.0590 - val_accuracy: 0.9828
# Epoch 9/50
# 192/192 [==============================] - 7s 37ms/step - loss: 0.1604 - accuracy: 0.9502 - val_loss: 0.0555 - val_accuracy: 0.9834
# Epoch 10/50
# 192/192 [==============================] - 7s 38ms/step - loss: 0.1517 - accuracy: 0.9537 - val_loss: 0.0538 - val_accuracy: 0.9833
# Epoch 11/50
ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 192/192 [==============================] - 7s 38ms/step - loss: 0.0807 - accuracy: 0.9759 - val_loss: 0.0300 - val_accuracy: 0.9910
# Epoch 45/50
# 192/192 [==============================] - 7s 37ms/step - loss: 0.0824 - accuracy: 0.9754 - val_loss: 0.0300 - val_accuracy: 0.9910
# Epoch 46/50
# 192/192 [==============================] - 7s 37ms/step - loss: 0.0834 - accuracy: 0.9742 - val_loss: 0.0300 - val_accuracy: 0.9909
# Epoch 47/50
# 191/192 [============================>.] - ETA: 0s - loss: 0.0828 - accuracy: 0.9745
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 192/192 [==============================] - 7s 37ms/step - loss: 0.0828 - accuracy: 0.9744 - val_loss: 0.0300 - val_accuracy: 0.9909
# Epoch 48/50
# 192/192 [==============================] - 7s 37ms/step - loss: 0.0819 - accuracy: 0.9754 - val_loss: 0.0300 - val_accuracy: 0.9909
# Epoch 49/50
# 192/192 [==============================] - 7s 37ms/step - loss: 0.0818 - accuracy: 0.9755 - val_loss: 0.0300 - val_accuracy: 0.9909
# Epoch 50/50
# 191/192 [============================>.] - ETA: 0s - loss: 0.0833 - accuracy: 0.9748
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 192/192 [==============================] - 7s 37ms/step - loss: 0.0834 - accuracy: 0.9747 - val_loss: 0.0300 - val_accuracy: 0.9909

# %%
acc_MNIST = history_MNIST.history['accuracy']
val_acc_MNIST = history_MNIST.history['val_accuracy']
loss_MNIST = history_MNIST.history['loss']
val_loss_MNIST = history_MNIST.history['val_loss']
epochs_graph = range(1, len(acc_MNIST) + 1)

plt.title('Training and Validation Accuracy', fontsize = '24')
plt.xlabel("Epochs", fontsize = '24')
plt.ylabel("Accuracy", fontsize = '24')
plt.xticks(fontsize = '20')
plt.yticks(fontsize = '20')
plt.plot(epochs_graph, acc_MNIST, 'red', label='Training accuracy')
plt.plot(epochs_graph, val_acc_MNIST, 'blue', label='Validation accuracy')
plt.legend()

plt.figure()
plt.title('Training and Validation Loss', fontsize = '24')
plt.xticks(fontsize = '20')
plt.yticks(fontsize = '20')
plt.xlabel("Epochs", fontsize = '24')
plt.ylabel("Loss", fontsize = '24')
plt.plot(epochs_graph, loss_MNIST, 'red', label='Training loss')
plt.plot(epochs_graph, val_loss_MNIST, 'blue', label='Validation loss')

plt.legend()

plt.show()

# %%
Y_pred_MNIST = model_MNIST.predict(X_test_MNIST)
Y_pred_classes_MNIST = np.argmax(Y_pred_MNIST, axis = 1) 
Y_truth_MNIST = np.argmax(Y_test_MNIST, axis = 1) 

confusion_mtx_MNIST = confusion_matrix(Y_truth_MNIST, Y_pred_classes_MNIST)

f, ax = plt.subplots(figsize=(16, 10))
sns.heatmap(confusion_mtx_MNIST, annot=True, linewidths=0.01, cmap="viridis", linecolor="gray", fmt= '.1f', ax = ax)
plt.xlabel("Predicted Label", fontsize = 24)
plt.ylabel("True Label", fontsize = 24)
plt.xticks(fontsize = '20')
plt.yticks(fontsize = '20')
plt.title("Confusion Matrix", fontsize = '24')
plt.show()

# %%
np.sum(Y_truth_MNIST == Y_pred_classes_MNIST) / len(Y_truth_MNIST)
# Out:
# 0.9922

# %%
errors_MNIST = (Y_pred_classes_MNIST - Y_truth_MNIST != 0)

Y_pred_classes_errors_MNIST = Y_pred_classes_MNIST[errors_MNIST]
Y_pred_errors_MNIST = Y_pred_MNIST[errors_MNIST]
Y_true_errors_MNIST = Y_truth_MNIST[errors_MNIST]
X_test_errors_MNIST = X_test_MNIST[errors_MNIST]


Y_pred_errors_prob_MNIST = np.max(Y_pred_errors_MNIST, axis = 1)
True_prob_errors_MNIST = np.diagonal(np.take(Y_pred_errors_MNIST, Y_true_errors_MNIST, axis=1))
Delta_pred_true_errors_MNIST = Y_pred_errors_prob_MNIST - True_prob_errors_MNIST
Sorted_dela_errors_MNIST = np.argsort(Delta_pred_true_errors_MNIST)
Most_important_errors_MNIST = Sorted_dela_errors_MNIST[-16:]

display_errors(Most_important_errors_MNIST, X_test_errors_MNIST, Y_pred_classes_errors_MNIST, Y_true_errors_MNIST, 28, 28, 4, 4)

# %%
Data = np.transpose(np.loadtxt("Digits_Dataset.txt"))
Data = Data.transpose()
Data = Data.astype(int)
Data.shape
# Out:
# (2000, 240)

# %%
x = 0
Classes = np.array([])
Classes = Classes.astype(int)

for i in range(1, 2001):
    Classes = np.append(Classes, x)
    if(i != 0 and i % 200 == 0):
        x = x + 1
        continue

# %%
batch_size = 25

# %%
X_Digits, X_test_Digits, Y_Digits, Y_test_Digits = train_test_split(Data, Classes, test_size=0.2, stratify = Classes, random_state=10)

# %%
Y_Digits_Total = np.concatenate((Y_Digits, Y_test_Digits), axis = None)

# %%
plt.figure()
g = sns.countplot(Y_Digits_Total, palette="icefire")
plt.title("Number of Digits Per Class", fontsize = '24')
plt.xticks(fontsize = '20')
plt.yticks(fontsize = '20')
plt.xlabel("Label", fontsize = '24')
plt.ylabel("Count", fontsize = '24')
Values, Counts = np.unique(Y_Digits_Total, return_counts=True)

# %%
VC_Digits = pd.DataFrame({'Values': Values, 'Counts': Counts})
VC_Digits = VC_Digits.style.hide_index()
VC_Digits
# Out:
# <style  type="text/css" >
# </style><table id="T_9436f_" ><thead>    <tr>        <th class="col_heading level0 col0" >Values</th>        <th class="col_heading level0 col1" >Counts</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_9436f_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_9436f_row0_col1" class="data row0 col1" >200</td>
#             </tr>
#             <tr>
#                                 <td id="T_9436f_row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_9436f_row1_col1" class="data row1 col1" >200</td>
#             </tr>
#             <tr>
#                                 <td id="T_9436f_row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_9436f_row2_col1" class="data row2 col1" >200</td>
#             </tr>
#             <tr>
#                                 <td id="T_9436f_row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_9436f_row3_col1" class="data row3 col1" >200</td>
#             </tr>
#             <tr>
#                                 <td id="T_9436f_row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_9436f_row4_col1" class="data row4 col1" >200</td>
#             </tr>
#             <tr>
#                                 <td id="T_9436f_row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_9436f_row5_col1" class="data row5 col1" >200</td>
#             </tr>
#             <tr>
#                                 <td id="T_9436f_row6_col0" class="data row6 col0" >6</td>
#                         <td id="T_9436f_row6_col1" class="data row6 col1" >200</td>
#             </tr>
#             <tr>
#                                 <td id="T_9436f_row7_col0" class="data row7 col0" >7</td>
#                         <td id="T_9436f_row7_col1" class="data row7 col1" >200</td>
#             </tr>
#             <tr>
#                                 <td id="T_9436f_row8_col0" class="data row8 col0" >8</td>
#                         <td id="T_9436f_row8_col1" class="data row8 col1" >200</td>
#             </tr>
#             <tr>
#                                 <td id="T_9436f_row9_col0" class="data row9 col0" >9</td>
#                         <td id="T_9436f_row9_col1" class="data row9 col1" >200</td>
#             </tr>
#     </tbody></table>

# %%
X_Digits = X_Digits / 6.
X_test_Digits = X_test_Digits / 6.

# %%
X_Digits = X_Digits.reshape(-1, 16, 15, 1)
X_test_Digits = X_test_Digits.reshape (-1, 16, 15, 1)
X_Digits.shape, X_test_Digits.shape
# Out:
# ((1600, 16, 15, 1), (400, 16, 15, 1))

# %%
Y_Digits = to_categorical(Y_Digits)
Y_test_Digits = to_categorical(Y_test_Digits)
Y_Digits.shape, Y_test_Digits.shape
# Out:
# ((1600, 10), (400, 10))

# %%
X_train_Digits, X_val_Digits, Y_train_Digits, Y_val_Digits = train_test_split(X_Digits, Y_Digits, test_size = 0.2, random_state=10, stratify = Y_Digits)
X_train_Digits.shape, X_val_Digits.shape, Y_train_Digits.shape, Y_val_Digits.shape
# Out:
# ((1280, 16, 15, 1), (320, 16, 15, 1), (1280, 10), (320, 10))

# %%
num = 20
images = X_Digits[:num]

num_row = 5
num_col = 4

fig, axes = plt.subplots(num_row, num_col, figsize=(10, 10))

for i in range(num):
    ax = axes[i // num_col, i % num_col]
    ax.imshow(images[i].reshape(16, 15), cmap='gray')
    ax.set_title('Label: {}'.format(Y_Digits[i].tolist().index(1.0, 0, 10)))
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xticklabels([])
    ax.set_yticklabels([])

plt.tight_layout()
plt.show()

# %%
datagen_Digits = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # dimesion reduction
        rotation_range=5,  # randomly rotate images in the range 5 degrees
        zoom_range = 0.1, # Randomly zoom image 10%
        width_shift_range=0.1,  # randomly shift images horizontally 10%
        height_shift_range=0.1,  # randomly shift images vertically 10%
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

datagen_Digits.fit(X_train_Digits)

# %%
model_Digits = Sequential()
model_Digits.add(Conv2D(filters = 8, kernel_size = (5, 5), padding = 'Same', activation = 'relu', input_shape = (16, 15, 1)))
model_Digits.add(MaxPool2D(pool_size=(2, 2)))
model_Digits.add(Dropout(0.25))
model_Digits.add(Conv2D(filters = 16, kernel_size = (3, 3), padding = 'Same', activation = 'relu'))
model_Digits.add(MaxPool2D(pool_size = (2, 2), strides = (2, 2)))
model_Digits.add(Dropout(0.25))
model_Digits.add(Flatten())
model_Digits.add(Dense(256, activation = "relu"))
model_Digits.add(Dropout(0.5))
model_Digits.add(Dense(10, activation = "softmax"))
model_Digits.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 16, 15, 8)         208
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 7, 8)           0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 7, 8)           0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 7, 16)          1168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 3, 16)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 3, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 192)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               49408
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 53,354
# Trainable params: 53,354
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model_Digits, "Digits_Classifier.png", show_shapes=True)
# Out:
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.

# %%
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999)
model_Digits.compile(optimizer = optimizer, loss = "categorical_crossentropy", metrics=["accuracy"])

# %%
history_Digits = model_Digits.fit_generator(datagen_Digits.flow(X_train_Digits, Y_train_Digits, batch_size = batch_size), epochs = epochs, validation_data = (X_val_Digits, Y_val_Digits), steps_per_epoch = X_train_Digits.shape[0] // batch_size, callbacks = callbacks)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 51 steps, validate on 320 samples
# Epoch 1/50
# 51/51 [==============================] - 1s 14ms/step - loss: 2.2250 - accuracy: 0.1777 - val_loss: 1.9575 - val_accuracy: 0.4719
# Epoch 2/50
# 51/51 [==============================] - 0s 5ms/step - loss: 1.7051 - accuracy: 0.3968 - val_loss: 0.9765 - val_accuracy: 0.7969
# Epoch 3/50
# 51/51 [==============================] - 0s 5ms/step - loss: 1.1350 - accuracy: 0.5992 - val_loss: 0.5016 - val_accuracy: 0.8906
# Epoch 4/50
# 51/51 [==============================] - 0s 5ms/step - loss: 0.8971 - accuracy: 0.6916 - val_loss: 0.3819 - val_accuracy: 0.9250
# Epoch 5/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7194 - accuracy: 0.7665 - val_loss: 0.2683 - val_accuracy: 0.9594
# Epoch 6/50
# 51/51 [==============================] - 0s 5ms/step - loss: 0.6899 - accuracy: 0.7538 - val_loss: 0.2425 - val_accuracy: 0.9563
# Epoch 7/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.5961 - accuracy: 0.8000 - val_loss: 0.1850 - val_accuracy: 0.9563
# Epoch 8/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4963 - accuracy: 0.8255 - val_loss: 0.1561 - val_accuracy: 0.9656
# Epoch 9/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4876 - accuracy: 0.8335 - val_loss: 0.1482 - val_accuracy: 0.9719
# Epoch 10/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4360 - accuracy: 0.8574 - val_loss: 0.1211 - val_accuracy: 0.9625
# Epoch 11/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4284 - accuracy: 0.8653 - val_loss: 0.1160 - val_accuracy: 0.9656
# Epoch 12/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.3605 - accuracy: 0.8869 - val_loss: 0.1024 - val_accuracy: 0.9625
# Epoch 13/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.3727 - accuracy: 0.8725 - val_loss: 0.0936 - val_accuracy: 0.9844
# Epoch 14/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.3371 - accuracy: 0.8900 - val_loss: 0.0868 - val_accuracy: 0.9688
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 51/51 [==============================] - 0s 5ms/step - loss: 0.2315 - accuracy: 0.9275 - val_loss: 0.0693 - val_accuracy: 0.9750
# Epoch 31/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.1953 - accuracy: 0.9386 - val_loss: 0.0683 - val_accuracy: 0.9750
# Epoch 32/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.2062 - accuracy: 0.9386 - val_loss: 0.0681 - val_accuracy: 0.9750
# Epoch 33/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.2061 - accuracy: 0.9450 - val_loss: 0.0686 - val_accuracy: 0.9750
# Epoch 34/50
# 42/51 [=======================>......] - ETA: 0s - loss: 0.2246 - accuracy: 0.9330
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 51/51 [==============================] - 0s 4ms/step - loss: 0.2310 - accuracy: 0.9323 - val_loss: 0.0680 - val_accuracy: 0.9750
# Epoch 35/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.2253 - accuracy: 0.9291 - val_loss: 0.0680 - val_accuracy: 0.9750
# Epoch 36/50
# 51/51 [==============================] - 0s 5ms/step - loss: 0.2168 - accuracy: 0.9371 - val_loss: 0.0679 - val_accuracy: 0.9750
# Epoch 37/50
# 41/51 [=======================>......] - ETA: 0s - loss: 0.1883 - accuracy: 0.9393
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 51/51 [==============================] - 0s 5ms/step - loss: 0.2049 - accuracy: 0.9363 - val_loss: 0.0680 - val_accuracy: 0.9750
# Epoch 38/50
# 51/51 [==============================] - 0s 5ms/step - loss: 0.2064 - accuracy: 0.9315 - val_loss: 0.0680 - val_accuracy: 0.9750
# Epoch 39/50
# 51/51 [==============================] - 0s 5ms/step - loss: 0.1981 - accuracy: 0.9315 - val_loss: 0.0680 - val_accuracy: 0.9750
# Epoch 40/50
# 41/51 [=======================>......] - ETA: 0s - loss: 0.1913 - accuracy: 0.9343
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 51/51 [==============================] - 0s 5ms/step - loss: 0.1961 - accuracy: 0.9323 - val_loss: 0.0680 - val_accuracy: 0.9750
# Epoch 41/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.1985 - accuracy: 0.9307 - val_loss: 0.0680 - val_accuracy: 0.9750
# Epoch 42/50
# 51/51 [==============================] - 0s 5ms/step - loss: 0.2221 - accuracy: 0.9323 - val_loss: 0.0680 - val_accuracy: 0.9750
# Epoch 43/50
# 42/51 [=======================>......] - ETA: 0s - loss: 0.2360 - accuracy: 0.9223
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 51/51 [==============================] - 0s 4ms/step - loss: 0.2233 - accuracy: 0.9267 - val_loss: 0.0680 - val_accuracy: 0.9750
# Epoch 00043: early stopping

# %%
acc_Digits = history_Digits.history['accuracy']
val_acc_Digits = history_Digits.history['val_accuracy']
loss_Digits = history_Digits.history['loss']
val_loss_Digits = history_Digits.history['val_loss']
epochs_graph = range(1, len(acc_Digits) + 1)

plt.title('Training and Validation Accuracy', fontsize = '24')
plt.xlabel("Epochs", fontsize = '24')
plt.ylabel("Accuracy", fontsize = '24')
plt.xticks(fontsize = '20')
plt.yticks(fontsize = '20')
plt.plot(epochs_graph, acc_Digits, 'red', label='Training accuracy')
plt.plot(epochs_graph, val_acc_Digits, 'blue', label='Validation accuracy')
plt.legend()

plt.figure()
plt.title('Training and Validation Loss', fontsize = '24')
plt.xlabel("Epochs", fontsize = '24')
plt.ylabel("Loss", fontsize = '24')
plt.xticks(fontsize = '20')
plt.yticks(fontsize = '20')
plt.plot(epochs_graph, loss_Digits, 'red', label='Training loss')
plt.plot(epochs_graph, val_loss_Digits, 'blue', label='Validation loss')
plt.legend()

plt.show()

# %%
Y_pred_Digits = model_Digits.predict(X_test_Digits)
Y_pred_classes_Digits = np.argmax(Y_pred_Digits, axis = 1) 
Y_truth_Digits = np.argmax(Y_test_Digits, axis = 1) 

confusion_mtx_Digits = confusion_matrix(Y_truth_Digits, Y_pred_classes_Digits)

f, ax = plt.subplots(figsize=(16, 10))
sns.heatmap(confusion_mtx_Digits, annot=True, linewidths=0.01, cmap="viridis", linecolor="gray", fmt= '.1f', ax = ax)
plt.xlabel("Predicted Label", fontsize = '24')
plt.ylabel("True Label", fontsize = '24')
plt.xticks(fontsize = '20')
plt.yticks(fontsize = '20')
plt.title("Confusion Matrix", fontsize = '24')
plt.show()

# %%
np.sum(Y_truth_Digits == Y_pred_classes_Digits) / len(Y_truth_Digits)
# Out:
# 0.99

# %%
errors_Digits = (Y_pred_classes_Digits - Y_truth_Digits != 0)

Y_pred_classes_errors_Digits = Y_pred_classes_Digits[errors_Digits]
Y_pred_errors_Digits = Y_pred_Digits[errors_Digits]
Y_true_errors_Digits = Y_truth_Digits[errors_Digits]
X_test_errors_Digits = X_test_Digits[errors_Digits]

Y_pred_errors_prob_Digits = np.max(Y_pred_errors_Digits, axis = 1)
True_prob_errors_Digits = np.diagonal(np.take(Y_pred_errors_Digits, Y_true_errors_Digits, axis=1))
Delta_pred_true_errors_Digits = Y_pred_errors_prob_Digits - True_prob_errors_Digits
Sorted_dela_errors_Digits = np.argsort(Delta_pred_true_errors_Digits)
Most_important_errors_Digits = Sorted_dela_errors_Digits[-16:]


display_errors(Most_important_errors_Digits, X_test_errors_Digits, Y_pred_classes_errors_Digits, Y_true_errors_Digits, 16, 15, 2, 4)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-c8f013920138> in <module>
#      13
#      14
# ---> 15 display_errors(Most_important_errors_Digits, X_test_errors_Digits, Y_pred_classes_errors_Digits, Y_true_errors_Digits, 16, 15, 2, 4)
#
# <ipython-input-2-af6ff99a91f7> in display_errors(errors_index, img_errors, pred_errors, obs_errors, x, y, nrows, ncols)
#       8     for row in range(nrows):
#       9         for col in range(ncols):
# ---> 10             error = errors_index[n]
#      11             ax[row, col].imshow((img_errors[error]).reshape((x, y)),  cmap = "gray")
#      12             ax[row, col].set_title("Predicted label: {}\nTrue label: {}".format(pred_errors[error], obs_errors[error]))
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %% [markdown]
# # Load previous models

# %% [markdown]
# ## MNIST

# %%
model_MNIST.save('saved_models/MNIST_Model')

# %%
model_MNIST = tensorflow.keras.models.load_model('saved_models/MNIST_Model')
model_MNIST.summary()

# %%
loss_MNIST, acc_MNIST = model_MNIST.evaluate(X_test_MNIST, Y_test_MNIST, verbose=2)

# %% [markdown]
# ## Digits

# %%
model_Digits.save('saved_models/Digits_Model')

# %%
model_Digits = tensorflow.keras.models.load_model('saved_models/Digits_Model')
model_Digits.summary()

# %%
loss_Digits, acc_Digits = model_Digits.evaluate(X_test_Digits, Y_test_Digits, verbose=2)

# %% [markdown]
# # Visualize activations

# %%
test_im = X_train_MNIST[154]
test_im = test_im.reshape((1,) + test_im.shape)

# %%
test_im = X_train_MNIST[154]
plt.xticks(fontsize = '0')
plt.yticks(fontsize = '0')
plt.grid(False)
plt.imshow(test_im, cmap = 'gray')

# %%
layer_outputs = [layer.output for layer in model_MNIST.layers]
feature_map_model = tensorflow.keras.models.Model(model_MNIST.input, layer_outputs)
feature_maps = feature_map_model.predict(test_im)

# %%
layer_names = []
for layer in model_MNIST.layers:
    layer_names.append(layer.name) 
images_per_row = 4
for layer_name, layer_activation in zip(layer_names, feature_maps):
    if layer_name.startswith('conv'):
        n_features = layer_activation.shape[-1]
        size = layer_activation.shape[1]
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0,:, :, col * images_per_row + row]
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.xticks(fontsize = '0')
        plt.yticks(fontsize = '0')
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='gray')

# %%
for layer_name, layer_activation in zip(layer_names, feature_maps):
    if layer_name.startswith('max'):
        n_features = layer_activation.shape[-1]
        size = layer_activation.shape[1]
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0,:, :, col * images_per_row + row]
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.xticks(fontsize = '0')
        plt.yticks(fontsize = '0')
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='gray')

# %% [markdown]
# # Visualize data augmentation

# %%
gen = datagen_MNIST.flow(X_train_MNIST, batch_size = batch_size)
x = gen.next()
for i in range(0,18):
    image = x[i]
    plt.imshow(image)
    plt.show()
